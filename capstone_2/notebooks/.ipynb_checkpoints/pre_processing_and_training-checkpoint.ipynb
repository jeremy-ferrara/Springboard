# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import entropy
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df_chords = pd.read_csv("../data/df_jazz_chords.csv")
df_chords.head()
# Out:
#           Title     Composer  Key        Rhythm Time Signature Section  \
# 0  9.20 Special  Earl Warren  NaN  Medium Swing            4/4       A
# 1  9.20 Special  Earl Warren  NaN  Medium Swing            4/4       A
# 2  9.20 Special  Earl Warren  NaN  Medium Swing            4/4       A
# 3  9.20 Special  Earl Warren  NaN  Medium Swing            4/4       A
# 4  9.20 Special  Earl Warren  NaN  Medium Swing            4/4       A
#
#    Measure  Chord Index Chord  Year Roman Numeral Root  Root_pc Chord_clean  \
# 0        0            0    D9  1941           NaN    D      2.0          D9
# 1        1            1   Fm6  1941           NaN    F      5.0         Fm6
# 2        2            2    D9  1941           NaN    D      2.0          D9
# 3        3            3   Fm6  1941           NaN    F      5.0         Fm6
# 4        4            4     C  1941           NaN    C      0.0           C
#
#   Chord Type Chord Extension
# 0      Triad               9
# 1      Triad               6
# 2      Triad               9
# 3      Triad               6
# 4      Triad    No extension

# %%
#define helper functions for computing model features

def compute_root_motion(root_pcs):
    diffs = root_pcs.diff().dropna()
    return np.minimum(np.abs(diffs), 12 - np.abs(diffs))

def pitch_class_entropy(root_pcs):
    counts = root_pcs.value_counts(normalize=True)
    return entropy(counts)

# %%
# define function for extracting song features for our model

def extract_song_features(song_df):
    features = {}

    # ------------------------
    # Basic structure
    # ------------------------
    features["n_chords"] = len(song_df)
    features["n_measures"] = song_df["Measure"].nunique()
    features["chords_per_measure"] = (
        features["n_chords"] / features["n_measures"]
        if features["n_measures"] > 0 else 0
    )

    # ------------------------
    # Harmonic vocabulary
    # ------------------------
    chord_types = song_df["Chord Type"].value_counts(normalize=True)

    features["pct_triad"] = chord_types.get("Triad", 0)
    features["pct_maj7"] = chord_types.get("Maj7", 0)
    features["pct_m7"] = chord_types.get("m7", 0)
    features["pct_dominant"] = chord_types.get("7", 0)
    features["pct_diminished"] = chord_types.get("o7", 0) + chord_types.get("ø7", 0)

    # Extensions
    extensions = pd.to_numeric(song_df["Chord Extension"], errors="coerce")
    features["pct_extensions_9plus"] = (extensions >= 9).mean()

    # ------------------------
    # Root motion
    # ------------------------
    root_pcs = song_df["Root_pc"].dropna()

    if len(root_pcs) > 1:
        motion = compute_root_motion(root_pcs)
        features["mean_root_motion"] = motion.mean()

        # Descending fifth = +5 mod 12
        features["pct_desc_fifth"] = (motion == 5).mean()
    else:
        features["mean_root_motion"] = 0
        features["pct_desc_fifth"] = 0

    # ------------------------
    # Tonal stability
    # ------------------------
    features["root_pc_entropy"] = (
        pitch_class_entropy(root_pcs)
        if len(root_pcs) > 0 else 0
    )

    # ------------------------
    # Metadata (single-valued)
    # ------------------------
    features["Rhythm"] = song_df["Rhythm"].iloc[0]
    features["TimeSignature"] = song_df["Time Signature"].iloc[0]
    features["Year"] = song_df["Year"].iloc[0]
    features["Key"] = song_df["Key"].iloc[0]

    return features

# %%
song_features = (
    df_chords
    .groupby("Title")
    .apply(extract_song_features)
    .apply(pd.Series)
    .reset_index()
)
# Out:
# /var/folders/r0/mxnnbvln7wl__9w60hwgw01c0000gn/T/ipykernel_3359/1865277365.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(extract_song_features)

# %%
song_features.head()
# Out:
#                Title  n_chords  n_measures  chords_per_measure  pct_triad  \
# 0               26-2        58           8            7.250000   0.000000
# 1     500 Miles High        22          18            1.222222   0.000000
# 2          502 Blues        22          20            1.100000   0.000000
# 3  52nd Street Theme        38           8            4.750000   0.315789
# 4       9.20 Special        37          10            3.700000   0.459459
#
#    pct_maj7    pct_m7  pct_dominant  pct_diminished  pct_extensions_9plus  \
# 0  0.379310  0.155172      0.465517        0.000000              0.000000
# 1  0.181818  0.545455      0.136364        0.136364              0.136364
# 2  0.227273  0.272727      0.318182        0.181818              0.227273
# 3  0.000000  0.315789      0.368421        0.000000              0.000000
# 4  0.000000  0.000000      0.513514        0.000000              0.189189
#
#    mean_root_motion  pct_desc_fifth  root_pc_entropy           Rhythm  \
# 0          3.929825        0.578947         2.191928  Medium Up Swing
# 1          1.523810        0.142857         2.161287       Bossa Nova
# 2          3.571429        0.523810         1.943998            Waltz
# 3          3.945946        0.675676         1.489767   Up Tempo Swing
# 4          2.685714        0.371429         1.859337     Medium Swing
#
#   TimeSignature  Year   Key
# 0           4/4  1947     F
# 1           4/4  1972  Emin
# 2           3/4  1959  Amin
# 3           4/4  1947   NaN
# 4           4/4  1941   NaN

# %%
song_features.dtypes
# Out:
# Title                    object
# n_chords                  int64
# n_measures                int64
# chords_per_measure      float64
# pct_triad               float64
# pct_maj7                float64
# pct_m7                  float64
# pct_dominant            float64
# pct_diminished          float64
# pct_extensions_9plus    float64
# mean_root_motion        float64
# pct_desc_fifth          float64
# root_pc_entropy         float64
# Rhythm                   object
# TimeSignature            object
# Year                     object
# Key                      object
# dtype: object

# %%
song_data = pd.read_csv("../data/song_data.csv")

# %%
song_data.head(30)
# Out:
#                                     Title                    Composer  \
# 0                            9.20 Special                 Earl Warren
# 1                                    26-2               John Coltrane
# 2                       52nd Street Theme             Thelonious Monk
# 3                          500 Miles High                 Chick Corea
# 4                               502 Blues                Jimmy Rowles
# 5                                A Ballad              Gerry Mulligan
# 6                  A Beautiful Friendship                 Donald Kahn
# 7                          A Blossom Fell            Barnes-Cornelius
# 8                         A Certain Smile                Fain-Webster
# 9                         A Child Is Born                Roland Hanna
# 10                           A Felicidade        Antonio-Carlos Jobim
# 11                         A Fine Romance                 Jerome Kern
# 12           A Flower Is A Lovesome Thing             Billy Strayhorn
# 13                            A Foggy Day             George Gershwin
# 14                    A Ghost Of A Chance                Victor Young
# 15             A Kiss To Build A Dream On     Kalmar-Ruby-Hammerstein
# 16                          A Little Tear               Deodato-Valle
# 17       A Lovely Way To Spend An Evening                Jimmy McHugh
# 18                     A Night In Tunisia             Dizzy Gillespie
# 19  A Nightingale Sang In Berkeley Square             Manning Sherwin
# 20         A Pretty Girl Is Like A Melody               Irving Berlin
# 21                        A Shade Of Jade               Joe Henderson
# 22                         A Sleepin' Bee                Harold Arlen
# 23                           A Smooth One               Benny Goodman
# 24                  A Sound For Sore Ears                 Jimmy Heath
# 25                  A Sunday Kind Of Love  Belle-Prima-Leonard-Rhodes
# 26                       A Taste Of Honey                Marlow-Scott
# 27                        A Time For Love               Johnny Mandel
# 28                      A Tisket A Tasket                 Traditional
# 29                     A Weaver Of Dreams                Victor Young
#
#              Rhythm TimeSignature  \
# 0      Medium Swing           4/4
# 1   Medium Up Swing           4/4
# 2    Up Tempo Swing           4/4
# 3        Bossa Nova           4/4
# 4             Waltz           3/4
# 5            Ballad           4/4
# 6      Medium Swing           4/4
# 7            Ballad           4/4
# 8      Medium Swing           4/4
# 9             Waltz           3/4
# 10       Bossa Nova           4/4
# 11     Medium Swing           4/4
# 12           Ballad           4/4
# 13     Medium Swing           4/4
# 14           Ballad           4/4
# 15     Medium Swing           4/4
# 16       Bossa Nova           4/4
# 17           Ballad           4/4
# 18            Latin           4/4
# 19           Ballad           4/4
# 20     Medium Swing           4/4
# 21   Up Tempo Swing           4/4
# 22     Medium Swing           4/4
# 23  Medium Up Swing           4/4
# 24        Even 8ths           4/4
# 25           Ballad           4/4
# 26            Waltz           3/4
# 27           Ballad           4/4
# 28     Medium Swing           4/4
# 29     Medium Swing           4/4
#
#                                              Sections   Key    Year
# 0   [{'Label': 'A', 'MainSegment': {'Chords': 'D9|...   NaN  1941.0
# 1   [{'Label': 'A', 'MainSegment': {'Chords': 'Fma...     F  1960.0
# 2   [{'Label': 'A', 'Repeats': 1, 'MainSegment': {...   NaN  1947.0
# 3   [{'MainSegment': {'Chords': 'Em7|Em7|Gm7|Gm7|B...  Emin  1972.0
# 4   [{'MainSegment': {'Chords': 'Am7|Dbmaj7|Bm7b5|...  Amin  1958.0
# 5   [{'Label': 'A', 'MainSegment': {'Chords': 'Dm7...   NaN     NaN
# 6   [{'Label': 'A', 'Repeats': 1, 'MainSegment': {...   NaN  1942.0
# 7   [{'Label': 'A', 'MainSegment': {'Chords': 'Bb6...    Bb  1954.0
# 8   [{'Label': 'A', 'MainSegment': {'Chords': 'Gm7...     F  1958.0
# 9   [{'Label': 'A', 'MainSegment': {'Chords': 'Bbm...    Bb  1965.0
# 10  [{'Label': 'A', 'Repeats': 1, 'MainSegment': {...  Amin  1958.0
# 11  [{'Label': 'A', 'MainSegment': {'Chords': 'C6|...   NaN  1936.0
# 12  [{'Label': 'A', 'Repeats': 1, 'MainSegment': {...    Db  1957.0
# 13  [{'Label': 'v', 'MainSegment': {'Chords': 'Fma...     F  1937.0
# 14  [{'MainSegment': {'Chords': 'Cmaj7|Db7#11|Gm7,...   NaN  1931.0
# 15  [{'Label': 'A', 'MainSegment': {'Chords': 'Cma...   NaN  1935.0
# 16  [{'Label': 'A', 'MainSegment': {'Chords': 'Eb9...    Db  1960.0
# 17  [{'Label': 'A', 'MainSegment': {'Chords': 'Bbm...     F  1943.0
# 18  [{'Label': 'A', 'Repeats': 1, 'MainSegment': {...  Dmin  1942.0
# 19  [{'Label': 'A', 'MainSegment': {'Chords': 'Ebm...    Eb  1939.0
# 20  [{'Label': 'A', 'MainSegment': {'Chords': 'A7,...     G  1919.0
# 21  [{'Label': 'A', 'Repeats': 1, 'MainSegment': {...  Cmin  1974.0
# 22  [{'Label': 'A', 'MainSegment': {'Chords': 'Abm...    Ab  1954.0
# 23  [{'Label': 'A', 'MainSegment': {'Chords': 'B07...     F  1941.0
# 24  [{'Label': 'A', 'MainSegment': {'Chords': 'Bb7...    Eb  1982.0
# 25  [{'Label': 'A', 'MainSegment': {'Chords': 'Fma...     F  1946.0
# 26  [{'Label': 'A', 'MainSegment': {'Chords': 'Dm|...  Dmin  1961.0
# 27  [{'Label': 'A', 'MainSegment': {'Chords': 'Fma...     F  1966.0
# 28  [{'Label': 'A', 'MainSegment': {'Chords': 'Ebm...    Eb  1938.0
# 29  [{'Label': 'A', 'MainSegment': {'Chords': 'Cma...   NaN  1960.0

# %%
song_features['Year'] = pd.to_numeric(song_data['Year'], errors='coerce')

# %%
song_features.head()
# Out:
#                Title  n_chords  n_measures  chords_per_measure  pct_triad  \
# 0               26-2        58           8            7.250000   0.000000
# 1     500 Miles High        22          18            1.222222   0.000000
# 2          502 Blues        22          20            1.100000   0.000000
# 3  52nd Street Theme        38           8            4.750000   0.315789
# 4       9.20 Special        37          10            3.700000   0.459459
#
#    pct_maj7    pct_m7  pct_dominant  pct_diminished  pct_extensions_9plus  \
# 0  0.379310  0.155172      0.465517        0.000000              0.000000
# 1  0.181818  0.545455      0.136364        0.136364              0.136364
# 2  0.227273  0.272727      0.318182        0.181818              0.227273
# 3  0.000000  0.315789      0.368421        0.000000              0.000000
# 4  0.000000  0.000000      0.513514        0.000000              0.189189
#
#    mean_root_motion  pct_desc_fifth  root_pc_entropy           Rhythm  \
# 0          3.929825        0.578947         2.191928  Medium Up Swing
# 1          1.523810        0.142857         2.161287       Bossa Nova
# 2          3.571429        0.523810         1.943998            Waltz
# 3          3.945946        0.675676         1.489767   Up Tempo Swing
# 4          2.685714        0.371429         1.859337     Medium Swing
#
#   TimeSignature    Year   Key
# 0           4/4  1941.0     F
# 1           4/4  1960.0  Emin
# 2           3/4  1947.0  Amin
# 3           4/4  1972.0   NaN
# 4           4/4  1958.0   NaN

# %%
# Convert categorical columns to dummies 

numeric_features = [
    "n_chords", "n_measures", "chords_per_measure",
    "pct_triad", "pct_maj7", "pct_m7", "pct_dominant", "pct_diminished",
    "pct_extensions_9plus", "mean_root_motion", "pct_desc_fifth", "root_pc_entropy", "Year"
]

categorical_features = ["Rhythm", "TimeSignature", "Key"]

song_features_processed = pd.get_dummies(
    song_features,
    columns=categorical_features,
    drop_first=True  
)

# %%
# Standardize numeric columns (after dealing with null values)

song_features_processed[numeric_features] = song_features_processed[numeric_features].replace('na', pd.NA)
song_features_processed[numeric_features] = song_features_processed[numeric_features].apply(pd.to_numeric, errors='coerce')
song_features_processed[numeric_features] = song_features_processed[numeric_features].fillna(song_features_processed[numeric_features].mean())

scaler = StandardScaler()
song_features_processed[numeric_features] = scaler.fit_transform(
    song_features_processed[numeric_features]
)

# %%
import joblib

joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
song_features_processed.head(30)
# Out:
#                                     Title  n_chords  n_measures  \
# 0                                    26-2  1.244329   -0.913729
# 1                          500 Miles High -1.321162    0.999274
# 2                               502 Blues -1.321162    1.381874
# 3                       52nd Street Theme -0.180944   -0.913729
# 4                            9.20 Special -0.252207   -0.531128
# 5                                A Ballad  2.954656    0.807974
# 6                  A Beautiful Friendship -0.893580   -0.913729
# 7                          A Blossom Fell -0.180944   -0.148528
# 8                         A Certain Smile -0.180944   -0.913729
# 9                         A Child Is Born -0.751053    0.616673
# 10                           A Felicidade  1.030538    0.616673
# 11                         A Fine Romance -0.323471   -0.913729
# 12           A Flower Is A Lovesome Thing -0.109680   -0.913729
# 13                            A Foggy Day  1.101802    1.190574
# 14                    A Ghost Of A Chance  0.175375   -0.531128
# 15             A Kiss To Build A Dream On  0.531693   -0.531128
# 16                          A Little Tear -0.323471    0.616673
# 17       A Lovely Way To Spend An Evening -0.180944   -0.531128
# 18                     A Night In Tunisia  0.175375    0.616673
# 19  A Nightingale Sang In Berkeley Square  2.170756   -0.148528
# 20         A Pretty Girl Is Like A Melody  0.460429    0.616673
# 21                        A Shade Of Jade  0.460429    0.616673
# 22                         A Sleepin' Bee  2.242020   -0.148528
# 23                           A Smooth One  0.175375   -0.722428
# 24                  A Sound For Sore Ears -1.036107   -0.913729
# 25                  A Sunday Kind Of Love  0.959274   -0.531128
# 26                       A Taste Of Honey -1.249898    0.234073
# 27                        A Time For Love  0.888011    0.234073
# 28                      A Tisket A Tasket -0.394734   -0.722428
# 29                     A Weaver Of Dreams -0.465998   -0.913729
#
#     chords_per_measure  pct_triad  pct_maj7    pct_m7  pct_dominant  \
# 0             2.102109  -0.897150  2.032590 -0.643598      0.410345
# 1            -1.394632  -0.897150  0.394162  2.166027     -1.502324
# 2            -1.465534  -0.897150  0.771260  0.202674     -0.445802
# 3             0.651848   0.881320 -1.114233  0.512677     -0.153868
# 4             0.042738   1.690444 -1.114233 -1.760678      0.689245
# 5             0.694503  -0.416385 -0.102505  1.136464     -0.381380
# 6            -0.073283  -0.696014  0.367226 -0.475150      0.818251
# 7            -0.266651   0.881320 -0.022631 -0.434554     -0.459704
# 8             0.651848  -0.156121  0.195689  1.081016     -0.612621
# 9            -1.015953   0.416942  0.821540 -0.800817     -0.164063
# 10           -0.109539  -0.897150  0.997520  0.988015     -0.604280
# 11            0.506822   0.197926 -0.883784  0.439004     -0.519172
# 12            0.724361  -0.319527  0.374823 -1.760678      1.132208
# 13           -0.393867   0.309669  0.515372 -0.089491     -0.323170
# 14            0.390801  -0.897150  0.043372  0.750587      0.137742
# 15            0.680853  -0.427832 -0.595722  1.388866     -0.236699
# 16           -0.798413   1.136563  1.420708 -0.360881     -1.649063
# 17            0.100749  -0.600738  0.195689  1.270463     -0.459704
# 18           -0.544618   0.281603 -0.535430 -0.923590      0.137742
# 19            1.328637  -0.579864  0.638479  0.976954     -1.067066
# 20           -0.399592   1.379544 -0.761204 -0.535323     -0.069276
# 21           -0.399592  -0.417846  3.828166 -0.075815     -2.047444
# 22            1.376979   0.041487  0.614136 -1.360736      1.014252
# 23            0.667962   2.377165 -1.114233 -1.593260     -1.213623
# 24           -0.218309  -0.897150  0.800268 -1.206912      1.728194
# 25            1.028916  -0.375685  0.422095 -0.027595     -0.142541
# 26           -1.150620   1.306606 -0.392827  0.117311     -1.031482
# 27            0.092461  -0.472107 -0.801170  0.955910      0.117344
# 28            0.152314  -0.253513  1.730168 -0.115202     -0.468442
# 29            0.361796  -0.897150  0.593802  0.780131     -0.072912
#
#     pct_diminished  pct_extensions_9plus  ...  Key_Eb  Key_Ebmin  Key_Emin  \
# 0        -0.914208             -0.716949  ...   False      False     False
# 1         1.305757              0.103649  ...   False      False      True
# 2         2.045745              0.650714  ...   False      False     False
# 3        -0.914208             -0.716949  ...   False      False     False
# 4        -0.914208              0.421538  ...   False      False     False
# 5        -0.120074              0.383853  ...   False      False     False
# 6         0.248631              0.142725  ...   False      False     False
# 7        -0.485794             -0.716949  ...   False      False     False
# 8        -0.485794             -0.558588  ...   False      False     False
# 9        -0.371550             -0.516358  ...   False      False     False
# 10        0.269773             -0.169883  ...   False      False     False
# 11        1.799082             -0.549790  ...   False      False     False
# 12        0.338080              1.751858  ...   False      False     False
# 13       -0.914208              0.035266  ...   False      False     False
# 14        0.600186             -0.157161  ...   False      False     False
# 15        0.103276             -0.215472  ...   False      False     False
# 16       -0.461993              1.957592  ...   False      False     False
# 17       -0.485794             -0.400227  ...   False      False     False
# 18        2.114581              0.962414  ...   False      False     False
# 19        0.002960             -0.716949  ...    True      False     False
# 20       -0.914208              0.691453  ...   False      False     False
# 21       -0.221453              2.483964  ...   False      False     False
# 22       -0.914208              0.787481  ...   False      False     False
# 23        2.493180             -0.577002  ...   False      False     False
# 24       -0.914208             -0.716949  ...    True      False     False
# 25       -0.311255             -0.716949  ...   False      False     False
# 26       -0.206393             -0.455309  ...   False      False     False
# 27        0.621617             -0.035698  ...   False      False     False
# 28       -0.914208             -0.716949  ...    True      False     False
# 29        0.043424             -0.008982  ...   False      False     False
#
#     Key_F  Key_F#min  Key_Fmin  Key_G  Key_G#min  Key_Gb  Key_Gmin
# 0    True      False     False  False      False   False     False
# 1   False      False     False  False      False   False     False
# 2   False      False     False  False      False   False     False
# 3   False      False     False  False      False   False     False
# 4   False      False     False  False      False   False     False
# 5   False      False     False  False      False   False     False
# 6   False      False     False  False      False   False     False
# 7   False      False     False  False      False   False     False
# 8    True      False     False  False      False   False     False
# 9   False      False     False  False      False   False     False
# 10  False      False     False  False      False   False     False
# 11  False      False     False  False      False   False     False
# 12  False      False     False  False      False   False     False
# 13   True      False     False  False      False   False     False
# 14  False      False     False  False      False   False     False
# 15  False      False     False  False      False   False     False
# 16  False      False     False  False      False   False     False
# 17   True      False     False  False      False   False     False
# 18  False      False     False  False      False   False     False
# 19  False      False     False  False      False   False     False
# 20  False      False     False   True      False   False     False
# 21  False      False     False  False      False   False     False
# 22  False      False     False  False      False   False     False
# 23   True      False     False  False      False   False     False
# 24  False      False     False  False      False   False     False
# 25   True      False     False  False      False   False     False
# 26  False      False     False  False      False   False     False
# 27   True      False     False  False      False   False     False
# 28  False      False     False  False      False   False     False
# 29  False      False     False  False      False   False     False
#
# [30 rows x 57 columns]

# %%
song_features_processed.to_csv(
    "../data/song_features_processed.csv",
    index=False
)
